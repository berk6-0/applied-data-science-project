# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# load
listings = pd.read_csv('listings.csv')
calendar = pd.read_csv('calendar.csv.gz', compression='gzip')
reviews = pd.read_csv('reviews.csv')
neighbourhoods = pd.read_csv('neighbourhoods.csv')
#  listings (3).csv.gz

# headers
print("Listings DataFrame:")
listings.head()

print("\nCalendar DataFrame:")
print(calendar.head())

print("\nReviews DataFrame:")
print(reviews.head())

print("\nNeighbourhoods DataFrame:")
print(neighbourhoods.head())
# Out:
# <ipython-input-28-c195c80bcc0f>:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   calendar = pd.read_csv('calendar.csv.gz', compression='gzip')
# Listings DataFrame:
#
# Calendar DataFrame:
#    listing_id        date available      price adjusted_price  minimum_nights  \
# 0     3078404  2024-06-29         f  $1,500.00            NaN             7.0
# 1     3078404  2024-06-30         f  $1,500.00            NaN             7.0
# 2     3078404  2024-07-01         f  $1,500.00            NaN             7.0
# 3     3078404  2024-07-02         f  $1,500.00            NaN             7.0
# 4     3078404  2024-07-03         f  $1,500.00            NaN             7.0
#
#    maximum_nights
# 0            20.0
# 1            20.0
# 2            20.0
# 3            20.0
# 4            20.0
#
# Reviews DataFrame:
#    listing_id        date
# 0       42932  2013-09-02
# 1       42932  2014-08-11
# 2       42932  2014-12-31
# 3       42932  2015-04-20
# 4       42932  2015-06-13
#
# Neighbourhoods DataFrame:
#    neighbourhood_group neighbourhood
# 0                  NaN          Alna
# 1                  NaN        Bjerke
# 2                  NaN       Frogner
# 3                  NaN    Gamle Oslo
# 4                  NaN        Grorud

# %%
# Exploratory Data Analysis

print("Listings dataset shape:", listings.shape)
print("Calendar dataset shape:", calendar.shape)
print("Reviews dataset shape:", reviews.shape)
print("Neighbourhoods dataset shape:", neighbourhoods.shape)

# info of each dataset
print("\nListings Info:")
print(listings.info())

print("\nCalendar Info:")
print(calendar.info())

print("\nReviews Info:")
print(reviews.info())

print("\nNeighbourhoods Info:")
print(neighbourhoods.info())
# Out:
# Listings dataset shape: (10099, 18)
# Calendar dataset shape: (3686136, 7)
# Reviews dataset shape: (167633, 2)
# Neighbourhoods dataset shape: (17, 2)
#
# Listings Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10099 entries, 0 to 10098
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10099 non-null  int64
#  1   name                            10099 non-null  object
#  2   host_id                         10099 non-null  int64
#  3   host_name                       10099 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   10099 non-null  object
#  6   latitude                        10099 non-null  float64
#  7   longitude                       10099 non-null  float64
#  8   room_type                       10099 non-null  object
#  9   price                           8850 non-null   float64
#  10  minimum_nights                  10099 non-null  int64
#  11  number_of_reviews               10099 non-null  int64
#  12  last_review                     7385 non-null   object
#  13  reviews_per_month               7385 non-null   float64
#  14  calculated_host_listings_count  10099 non-null  int64
#  15  availability_365                10099 non-null  int64
#  16  number_of_reviews_ltm           10099 non-null  int64
#  17  license                         0 non-null      float64
# dtypes: float64(6), int64(7), object(5)
# memory usage: 1.4+ MB
# None
#
# Calendar Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3686136 entries, 0 to 3686135
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 196.9+ MB
# None
#
# Reviews Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167633 entries, 0 to 167632
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  167633 non-null  int64
#  1   date        167633 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 2.6+ MB
# None
#
# Neighbourhoods Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        17 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 400.0+ bytes
# None

# %%
# missing values
print("\nMissing values in Listings:")
print(listings.isnull().sum())

print("\nMissing values in Calendar:")
print(calendar.isnull().sum())

print("\nMissing values in Reviews:")
print(reviews.isnull().sum())

print("\nMissing values in Neighbourhoods:")
print(neighbourhoods.isnull().sum())
# Out:
# Missing values in Listings:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               10099
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              1249
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        2714
# reviews_per_month                  2714
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           10099
# dtype: int64
#
# Missing values in Calendar:
# listing_id              0
# date                    0
# available               0
# price                   0
# adjusted_price    3684311
# minimum_nights          2
# maximum_nights          2
# dtype: int64
#
# Missing values in Reviews:
# listing_id    0
# date          0
# dtype: int64
#
# Missing values in Neighbourhoods:
# neighbourhood_group    17
# neighbourhood           0
# dtype: int64

# %%
# summary statistics
print("\nSummary statistics for Listings:")
print(listings.describe())

print("\nSummary statistics for Calendar:")
print(calendar.describe())

print("\nSummary statistics for Reviews:")
print(reviews.describe())

print("\nSummary statistics for Neighbourhoods:")
print(neighbourhoods.describe())
# Out:
# Summary statistics for Listings:
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.009900e+04  1.009900e+04                  0.0  10099.000000
# mean   7.277618e+17  1.755817e+08                  NaN     59.921761
# std    4.279843e+17  1.797291e+08                  NaN      0.020585
# min    4.293200e+04  4.306700e+04                  NaN     59.817260
# 25%    5.940418e+17  3.373941e+07                  NaN     59.913290
# 50%    9.005968e+17  9.303204e+07                  NaN     59.922820
# 75%    1.071329e+18  2.743167e+08                  NaN     59.931701
# max    1.189092e+18  5.860672e+08                  NaN     60.041562
#
#           longitude          price  minimum_nights  number_of_reviews  \
# count  10099.000000    8850.000000    10099.000000       10099.000000
# mean      10.759973    1691.398531        3.973067          16.598970
# std        0.043214    2297.924650       12.245705          43.616216
# min       10.591050     160.000000        1.000000           0.000000
# 25%       10.736792     971.000000        2.000000           0.000000
# 50%       10.762670    1304.500000        2.000000           4.000000
# 75%       10.779821    1902.750000        3.000000          14.000000
# max       10.942936  110000.000000      500.000000        1161.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# count        7385.000000                    10099.000000      10099.000000
# mean            1.224864                        2.466482        134.049609
# std             1.574437                        9.174954        122.260856
# min             0.010000                        1.000000          0.000000
# 25%             0.270000                        1.000000         22.000000
# 50%             0.660000                        1.000000         90.000000
# 75%             1.480000                        1.000000        241.000000
# max            13.210000                       94.000000        365.000000
#
#        number_of_reviews_ltm  license
# count           10099.000000      0.0
# mean                6.601347      NaN
# std                13.123750      NaN
# min                 0.000000      NaN
# 25%                 0.000000      NaN
# 50%                 2.000000      NaN
# 75%                 7.000000      NaN
# max               156.000000      NaN
#
# Summary statistics for Calendar:
#          listing_id  minimum_nights  maximum_nights
# count  3.686136e+06    3.686134e+06    3.686134e+06
# mean   7.277619e+17    4.126170e+00    3.933370e+02
# std    4.279632e+17    1.319028e+01    4.167281e+02
# min    4.293200e+04    1.000000e+00    1.000000e+00
# 25%    5.940407e+17    2.000000e+00    3.000000e+01
# 50%    9.005968e+17    2.000000e+00    3.650000e+02
# 75%    1.071575e+18    4.000000e+00    3.650000e+02
# max    1.189092e+18    5.000000e+02    1.500000e+03
#
# Summary statistics for Reviews:
#          listing_id
# count  1.676330e+05
# mean   3.318939e+17
# std    4.138161e+17
# min    4.293200e+04
# 25%    1.526710e+07
# 50%    4.533872e+07
# 75%    7.442357e+17
# max    1.187070e+18
#
# Summary statistics for Neighbourhoods:
#        neighbourhood_group
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=listings, y='neighbourhood', order=listings['neighbourhood'].value_counts().index)
plt.title('Number of Listings by Neighbourhood')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=listings, x='price', bins=30, kde=True)
plt.title('Price Distribution of Listings')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=calendar, x='available', kde=False)
plt.title('Availability Distribution in Calendar')
plt.show()

# %%
numeric_listings = listings.select_dtypes(include=['float64', 'int64'])

print(numeric_listings.head())

plt.figure(figsize=(12, 8))
sns.heatmap(numeric_listings.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for Listings Dataset')
plt.show()
# Out:
#        id  host_id  neighbourhood_group  latitude  longitude   price  \
# 0   42932   187463                  NaN  59.91201   10.72455  3400.0
# 1   71725   368229                  NaN  59.90795   10.77987   572.0
# 2   85902   250159                  NaN  59.91074   10.77232  1929.0
# 3  123041   250159                  NaN  59.91253   10.77205   736.0
# 4  149776   714768                  NaN  59.92398   10.74787  1029.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               4                 52               0.39
# 1              14                 56               0.34
# 2               3                 79               0.50
# 3               1                235               1.48
# 4               5                 43               0.27
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               2               297                      2
# 1                               1               281                      3
# 2                               2                26                      5
# 3                               2                 1                      4
# 4                               2               363                      0
#
#    license
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# ## Some more interesting and relevant findings:

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=listings, x='longitude', y='latitude', hue='price', palette='coolwarm', size='price', sizes=(40, 400), alpha=0.6)
plt.title('Price Distribution by Location')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
avg_price_neighborhood = listings.groupby('neighbourhood')['price'].mean().reset_index()

plt.figure(figsize=(10,6))
sns.barplot(data=avg_price_neighborhood, x='neighbourhood', y='price', palette='viridis')
plt.xticks(rotation=90)
plt.title('Average Price by Neighborhood')
plt.show()
# Out:
# <ipython-input-22-77ba174cd2a1>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_price_neighborhood, x='neighbourhood', y='price', palette='viridis')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=listings, x='neighbourhood', y='price')
plt.xticks(rotation=90)
plt.title('Price Distribution by Neighborhood')
plt.show()

# %%
calendar['date'] = pd.to_datetime(calendar['date'])

plt.figure(figsize=(10,6))
sns.lineplot(data=calendar, x='date', y='price', hue='listing_id', alpha=0.5, legend=False)
plt.title('Price Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=listings, x='availability_365', y='price', hue='price', palette='coolwarm')
plt.title('Price vs Availability')
plt.xlabel('Availability (Days per Year)')
plt.ylabel('Price')
plt.show()
